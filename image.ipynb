# %% [markdown]
# <a href="https://colab.research.google.com/github/preet8935/MLbootcamp/blob/master/image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("thor.jpg")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (194, 259, 3)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194 at 0x7F72769177F0>

# %%
cut=arr[:5,:5]
plt.imshow(cut)

# %%
plt.imshow(arr)

# %%
work=arr.copy()

# %%
work[:,:,[1,2]]=0
plt.imshow(work)

# %%
gray= arr.mean(axis=2)
plt.imshow(gray,cmap="gray")
#for gray image
